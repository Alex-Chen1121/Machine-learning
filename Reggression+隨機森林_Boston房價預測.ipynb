# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex-Chen1121/Machine-learning/blob/main/Reggression%2B%E9%9A%A8%E6%A9%9F%E6%A3%AE%E6%9E%97_Boston%E6%88%BF%E5%83%B9%E9%A0%90%E6%B8%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import boston_housing
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ##線上medium文章實作

# %%
type(boston_housing.load_data())
# Out:
# tuple

# %%
x_train.shape
# Out:
# (404, 13)

# %%
boston_test = pd.DataFrame(x_test, columns=["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT"])
boston_test.head()
# Out:
#        CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  18.08460  0.0  18.10   0.0  0.679  6.434  100.0  1.8347  24.0  666.0
# 1   0.12329  0.0  10.01   0.0  0.547  5.913   92.9  2.3534   6.0  432.0
# 2   0.05497  0.0   5.19   0.0  0.515  5.985   45.4  4.8122   5.0  224.0
# 3   1.27346  0.0  19.58   1.0  0.605  6.250   92.6  1.7984   5.0  403.0
# 4   0.07151  0.0   4.49   0.0  0.449  6.121   56.8  3.7476   3.0  247.0
#
#    PTRATIO       B  LSTAT
# 0     20.2   27.25  29.05
# 1     17.8  394.95  16.21
# 2     20.2  396.90   9.74
# 3     14.7  338.92   5.50
# 4     18.5  395.15   8.44

# %%
boston_test["MEDV"] = y_test
boston_test
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0    18.08460  0.0  18.10   0.0  0.679  6.434  100.0  1.8347  24.0  666.0
# 1     0.12329  0.0  10.01   0.0  0.547  5.913   92.9  2.3534   6.0  432.0
# 2     0.05497  0.0   5.19   0.0  0.515  5.985   45.4  4.8122   5.0  224.0
# 3     1.27346  0.0  19.58   1.0  0.605  6.250   92.6  1.7984   5.0  403.0
# 4     0.07151  0.0   4.49   0.0  0.449  6.121   56.8  3.7476   3.0  247.0
# ..        ...  ...    ...   ...    ...    ...    ...     ...   ...    ...
# 97    3.47428  0.0  18.10   1.0  0.718  8.780   82.9  1.9047  24.0  666.0
# 98    0.07896  0.0  12.83   0.0  0.437  6.273    6.0  4.2515   5.0  398.0
# 99    1.83377  0.0  19.58   1.0  0.605  7.802   98.2  2.0407   5.0  403.0
# 100   0.35809  0.0   6.20   1.0  0.507  6.951   88.5  2.8617   8.0  307.0
# 101   2.92400  0.0  19.58   0.0  0.605  6.101   93.0  2.2834   5.0  403.0
#
#      PTRATIO       B  LSTAT  MDEV  MEDV
# ...

# %%
boston = pd.DataFrame(x_train, columns=["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT"])
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
#
#    PTRATIO       B  LSTAT
# 0     21.0  396.90  18.72
# 1     14.7  395.38   3.11
# 2     20.2  375.52   3.26
# 3     20.2  396.90   8.01
# 4     20.2  391.43  14.65

# %%
y_train.shape
# Out:
# (404,)

# %%
boston["MEDV"] = y_train
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     21.0  396.90  18.72  15.2
# 1     14.7  395.38   3.11  42.3
# 2     20.2  375.52   3.26  50.0
# 3     20.2  396.90   8.01  21.1
# 4     20.2  391.43  14.65  17.7

# %%
# 讀出完整資料後 先進行資料預處理
# 確認是否有缺失值
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# 資料視覺化 大概看一下資料長怎樣
# 先設定圖的大小
sns.set(rc={"figure.figsize":(10,10)})

#設定要畫哪種類型的 指定資料
sns.distplot(boston["MEDV"])
plt.show()
# Out:
# <ipython-input-14-052a1ceb6419>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(boston["MEDV"])

# %%
correlation_matrix = boston.corr()
correlation_matrix
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.192179  0.397419 -0.050828  0.405765 -0.217597  0.344410
# ZN      -0.192179  1.000000 -0.533823 -0.041981 -0.521713  0.338683 -0.578728
# INDUS    0.397419 -0.533823  1.000000  0.052839  0.774200 -0.409924  0.656350
# CHAS    -0.050828 -0.041981  0.052839  1.000000  0.079803  0.040431  0.080488
# NOX      0.405765 -0.521713  0.774200  0.079803  1.000000 -0.335866  0.729338
# RM      -0.217597  0.338683 -0.409924  0.040431 -0.335866  1.000000 -0.240875
# AGE      0.344410 -0.578728  0.656350  0.080488  0.729338 -0.240875  1.000000
# DIS     -0.378590  0.650787 -0.725155 -0.083101 -0.777062  0.233970 -0.766670
# RAD      0.609689 -0.311091  0.599226 -0.024851  0.616535 -0.243990  0.462188
# TAX      0.575652 -0.303522  0.701362 -0.051343  0.673471 -0.307904  0.512746
# PTRATIO  0.273447 -0.403139  0.379284 -0.122008  0.188160 -0.367256  0.282193
# ...

# %%
correlation_matrix = boston.corr().round(2) # ROUND(2)取到小數點第二位
correlation_matrix
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.19   0.40 -0.05  0.41 -0.22  0.34 -0.38  0.61  0.58     0.27
# ZN      -0.19  1.00  -0.53 -0.04 -0.52  0.34 -0.58  0.65 -0.31 -0.30    -0.40
# INDUS    0.40 -0.53   1.00  0.05  0.77 -0.41  0.66 -0.73  0.60  0.70     0.38
# CHAS    -0.05 -0.04   0.05  1.00  0.08  0.04  0.08 -0.08 -0.02 -0.05    -0.12
# NOX      0.41 -0.52   0.77  0.08  1.00 -0.34  0.73 -0.78  0.62  0.67     0.19
# RM      -0.22  0.34  -0.41  0.04 -0.34  1.00 -0.24  0.23 -0.24 -0.31    -0.37
# AGE      0.34 -0.58   0.66  0.08  0.73 -0.24  1.00 -0.77  0.46  0.51     0.28
# DIS     -0.38  0.65  -0.73 -0.08 -0.78  0.23 -0.77  1.00 -0.51 -0.54    -0.24
# RAD      0.61 -0.31   0.60 -0.02  0.62 -0.24  0.46 -0.51  1.00  0.92     0.45
# TAX      0.58 -0.30   0.70 -0.05  0.67 -0.31  0.51 -0.54  0.92  1.00     0.44
# PTRATIO  0.27 -0.40   0.38 -0.12  0.19 -0.37  0.28 -0.24  0.45  0.44     1.00
# ...

# %%
correlation_matrix = boston.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)

# MEDV(房價)跟LSTAT 以及RM 這兩項有高度相關
# (DIS AGE) (INDUS ZN) 有有多元共線性的問題
# Out:
# <Axes: >

# %%
# 設定整張圖的長寬
plt.figure(figsize=(20, 5))
features = ["LSTAT", "RM"]
target = boston["MEDV"]
for i, col in enumerate(features):
 # 排版1 row, 2 columns, nth plot：在jupyter notebook上兩張並排
 plt.subplot(1, len(features) , i+1)
 # add data column into plot
 x = boston[col]
 y = target
 plt.scatter(x, y, marker="o")
 plt.title(col)
 plt.xlabel(col)
 plt.ylabel("MEDV")

# %%
X = pd.DataFrame(np.c_[boston["LSTAT"], boston["RM"]], columns = ["LSTAT", "RM"])
Y = boston["MEDV"]

X_train = X
Y_train = Y
print(X_train.shape)
print(Y_train.shape)
# Out:
# (404, 2)
# (404,)

# %%
X_test = pd.DataFrame(np.c_[boston_test["LSTAT"], boston_test["RM"]], columns = ["LSTAT", "RM"])
Y_test = boston_test["MEDV"]

# %%
# Modeling
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
# 學習/訓練Fitting linear model
reg.fit(X_train,Y_train)
# 預測結果Predicting using the linear model
reg.predict(X_test)
# 真實結果：Y_test
# 測試準確度：
print("R2:", reg.score(X_test, Y_test))
# Out:
# R2: 0.700683951997074

# %%
# plotting the y_test vs y_pred
Y_pred = reg.predict(X_test)
plt.scatter(Y_pred, Y_test)
plt.xlabel('Y_pred')
plt.ylabel('Y_test')
plt.show()

# %%
reg.intercept_
#output: 2.7362403426066138
coeff_df = pd.DataFrame(reg.coef_, X_train.columns, columns=['Coefficient'])
coeff_df
#output: Coefficient
#LSTAT -0.636989
#RM 4.866252
# Out:
#        Coefficient
# LSTAT    -0.636989
# RM        4.866252

# %%
# 最後得出房價預測公式 : MEDIV = 2.74 + (-0.717230) * LSTAT + 4.589388 * RM + error

# %%
linnerud_data=load_linnerud()
#先列出此資料集的欄位
print(linnerud_data.keys())
#DESCR這個資料集的詳細描述
print(linnerud_data['DESCR'])

# %%
#使用pandas列出表格
df=pd.DataFrame(linnerud_data.data,columns=linnerud_data.feature_names)
# df["target"]=linnerud_data["target"]
df.head()

# %% [markdown]
# ##tibame機器學習課程 回歸樹模型分析

# %%
boston_housing.load_data()

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor()
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
import graphviz
from sklearn.tree import export_graphviz

g = export_graphviz(reg, out_file=None,
           feature_names=["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT"],
           filled=True)
graphviz.Source(g)

# %% [markdown]
# mse:資料範圍的大小
# 越到決策樹的末端 mse越小
# mse = (fi-f平均)**

# %%
# 評估方式 我的預測跟準確值的差距
print("預測結果:",list(reg.predict(x_test)))
print("正確結果:",list(y_test))
# Out:
# 預測結果: [8.8, 18.4, 21.0, 22.1, 21.2, 21.8, 33.4, 24.8, 18.8, 19.9, 16.1, 19.6, 13.3, 39.8, 21.9, 21.7, 24.4, 19.3, 14.3, 21.6, 17.2, 19.1, 18.5, 23.1, 19.4, 21.4, 29.9, 29.1, 12.1, 20.3, 20.0, 10.4, 32.0, 22.3, 19.1, 8.8, 13.4, 19.6, 20.4, 29.1, 28.2, 26.5, 17.8, 48.3, 27.5, 26.4, 25.0, 19.4, 23.0, 22.6, 32.7, 19.4, 10.5, 13.5, 36.4, 26.5, 8.3, 48.8, 29.1, 22.6, 28.2, 17.8, 10.4, 19.3, 23.8, 23.5, 17.8, 23.5, 14.6, 10.8, 19.9, 33.1, 21.4, 14.3, 22.2, 18.5, 21.2, 23.9, 29.0, 7.0, 23.2, 43.5, 17.1, 16.7, 20.6, 16.5, 21.4, 15.2, 22.0, 28.2, 14.4, 20.4, 30.3, 43.8, 32.0, 18.3, 41.3, 38.7, 29.1, 48.5, 29.9, 24.0]
# ...

# %%
# 評估
from sklearn.metrics import r2_score
r2_score(y_test, reg.predict(x_test))
# Out:
# 0.787861613797515

# %%
mean = x_test.mean()
# Out:
# 71.18771368778282
